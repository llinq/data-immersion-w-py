# %% [markdown]
# <a href="https://colab.research.google.com/github/llinq/data-immersion-w-py/blob/main/Aula_0_de_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import this

# %%
tenis_nike = 250

# %%
tenis_nike
# Out:
# 250

# %%
idade = 18

if idade >= 18:
  print('Pode dirigir')
else:
  print('Não pode dirigir')
# Out:
# Pode dirigir
